# %% [markdown]
# <a href="https://colab.research.google.com/github/szholbarys/google-gemini-ai/blob/main/SIS_3(Saken_Zholbarys).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.4/137.4 kB 2.4 MB/s eta 0:00:00

# %%
import google.generativeai as  genai

# %%
API_KEY = 'AIzaSyAp0122S1VhrxnIWMTNpxxWhMHFDvcUVrY'

# %%
genai.configure(api_key=API_KEY)

# %%
geminiModel = genai.GenerativeModel("gemini-pro")

# %%
response = geminiModel.generate_content("Who is Shawn Mendes?")
print(response.text)
# Out:
# **Shawn Peter Raul Mendes**
#
# **Personal Information:**
#
# * Date of Birth: August 8, 1998
# * Birthplace: Pickering, Ontario, Canada
# * Nationality: Canadian
#
# **Career:**
#
# * Singer, songwriter
# * Plays guitar and piano
#
# **Musical Journey:**
#
# * Started posting cover songs on Vine in 2013
# * Signed with Island Records in 2014
# * Released his debut album, "Handwritten," in 2015
# * Has released four studio albums and numerous singles, including global hits like:
#     * "Stitches"
#     * "Treat You Better"
#     * "There's Nothing Holdin' Me Back"
#     * "In My Blood"
#     * "If I Can't Have You"
#
# **Accomplishments and Awards:**
#
# * Won multiple American Music Awards, MTV Video Music Awards, Juno Awards
# * Nominated for four Grammy Awards
# * Ranked among the world's most influential celebrities by Time magazine
# * Sold over 60 million records worldwide
#
# **Personal Life:**
#
# * Was in a relationship with singer Camila Cabello from 2019 to 2021
# ...

# %%
chatModel = geminiModel.start_chat(history=[])

# %%
response = chatModel.send_message("Who is Ronaldo?")
print(response.text)
# Out:
# **Cristiano Ronaldo dos Santos Aveiro** (born 5 February 1985), known as **Cristiano Ronaldo**, is a Portuguese professional footballer who plays as a forward for Saudi Arabian club Al Nassr and captains the Portugal national team. Widely regarded as one of the greatest players of all time, Ronaldo has won five Ballon d'Or awards and four European Golden Shoes, among other awards and accolades.
#
# **Playing career:**
#
# * Sporting CP (2002-2003)
# * Manchester United (2003-2009)
# * Real Madrid (2009-2018)
# * Juventus (2018-2021)
# * Manchester United (2021-2022)
# * Al Nassr (2023-present)
#
# **Individual awards and achievements:**
#
# * Ballon d'Or: 2008, 2013, 2014, 2016, 2017
# * FIFA World Player of the Year: 2008, 2016, 2017
# * UEFA Men's Player of the Year: 2014, 2016, 2017
# * European Golden Shoe: 2008, 2011, 2014, 2015
# * UEFA Champions League top scorer: 2008, 2013, 2014, 2015, 2016, 2017, 2018
# * FIFA Club World Cup Golden Ball: 2014, 2016, 2017
# ...

# %%
print(chatModel.history)
# Out:
# [parts {
#   text: "Can you write In My Blood lyrics?"
# }
# role: "user"
# , parts {
# ...

# %%
import PIL.Image

# %%
img = PIL.Image.open('/content/dlp3.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x474>

# %%
model = genai.GenerativeModel("gemini-pro-vision")
response = model.generate_content(img)

print(response.text)
# Out:
#  She's so pretty! I love her hair!

# %%
model.count_tokens("What is the meaning of life?")
# Out:
# total_tokens: 7

# %%
model.count_tokens(chatModel.history)
# Out:
# total_tokens: 1884
